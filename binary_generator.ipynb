# %%
n = 42 
b = f'{n:b}' 
print(b)

# %%
n =40
bin(40)
# Out:
# '0b101000'

# %%
for i in range(1,257):
    b = f'{i:b}' 
    #b= bin(i)
    print('The bainary value for ',+ i, 'is ',b)
# Out:
# The bainary value for  1 is  1
# The bainary value for  2 is  10
# The bainary value for  3 is  11
# The bainary value for  4 is  100
# The bainary value for  5 is  101
# The bainary value for  6 is  110
# The bainary value for  7 is  111
# The bainary value for  8 is  1000
# The bainary value for  9 is  1001
# The bainary value for  10 is  1010
# The bainary value for  11 is  1011
# The bainary value for  12 is  1100
# The bainary value for  13 is  1101
# The bainary value for  14 is  1110
# The bainary value for  15 is  1111
# The bainary value for  16 is  10000
# The bainary value for  17 is  10001
# The bainary value for  18 is  10010
# The bainary value for  19 is  10011
# The bainary value for  20 is  10100
# The bainary value for  21 is  10101
# The bainary value for  22 is  10110
# The bainary value for  23 is  10111
# The bainary value for  24 is  11000
# The bainary value for  25 is  11001
# The bainary value for  26 is  11010
# The bainary value for  27 is  11011
# ...
